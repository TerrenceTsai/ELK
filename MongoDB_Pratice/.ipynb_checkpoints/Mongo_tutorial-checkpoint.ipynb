# %%
from pymongo import MongoClient
# pprint library is used to make the output look more pretty
from pprint import pprint
# connect to MongoDB, change the << MONGODB URL >> to reflect your own connection string
client = MongoClient('localhost', 27017)
db=client.admin
# Issue the serverStatus command and print the results
serverStatusResult=db.command("serverStatus")
pprint(serverStatusResult)
# Out:
# {u'asserts': {u'msg': 0,
#               u'regular': 0,
#               u'rollovers': 0,
#               u'user': 0,
#               u'warning': 0},
#  u'backgroundFlushing': {u'average_ms': 6.580645161290323,
#                          u'flushes': 31,
#                          u'last_finished': datetime.datetime(2018, 1, 19, 3, 38, 47, 482000),
#                          u'last_ms': 6,
#                          u'total_ms': 204},
#  u'connections': {u'available': 815, u'current': 4, u'totalCreated': 29L},
#  u'cursors': {u'clientCursors_size': 0,
#               u'note': u'deprecated, use server status metrics',
#               u'pinned': 0,
#               u'timedOut': 0,
#               u'totalNoTimeout': 0,
#               u'totalOpen': 0},
#  u'dur': {u'commits': 29,
#           u'commitsInWriteLock': 0,
#           u'compression': 0.0,
#           u'earlyCommits': 0,
#           u'journaledMB': 0.0,
#           u'timeMs': {u'dt': 3024,
#                       u'prepLogBuffer': 0,
#                       u'remapPrivateView': 0,
#                       u'writeToDataFiles': 0,
#                       u'writeToJournal': 0},
#           u'writeToDataFilesMB': 0.0},
#  u'extra_info': {u'heap_usage_bytes': 62665424,
#                  u'note': u'fields vary by platform',
#                  u'page_faults': 24},
#  u'globalLock': {u'activeClients': {u'readers': 0,
#                                     u'total': 0,
#                                     u'writers': 0},
#                  u'currentQueue': {u'readers': 0, u'total': 0, u'writers': 0},
#                  u'lockTime': 176639L,
#                  u'totalTime': 1872629000L},
#  u'host': u'Ubuntu',
#  u'indexCounters': {u'accesses': 5,
#                     u'hits': 5,
#                     u'missRatio': 0.0,
#                     u'misses': 0,
#                     u'resets': 0},
#  u'localTime': datetime.datetime(2018, 1, 19, 3, 39, 0, 58000),
#  u'locks': {u'.': {u'timeAcquiringMicros': {u'R': 113200L, u'W': 4810L},
#                    u'timeLockedMicros': {u'R': 45025L, u'W': 176639L}},
#             u'admin': {u'timeAcquiringMicros': {u'r': 49L, u'w': 0L},
#                        u'timeLockedMicros': {u'r': 2831L, u'w': 0L}},
#             u'local': {u'timeAcquiringMicros': {u'r': 3116L, u'w': 0L},
#                        u'timeLockedMicros': {u'r': 13223L, u'w': 0L}},
#             u'test': {u'timeAcquiringMicros': {u'r': 86L, u'w': 0L},
#                       u'timeLockedMicros': {u'r': 283L, u'w': 0L}},
#             u'testdb': {u'timeAcquiringMicros': {u'r': 1112L, u'w': 14L},
#                         u'timeLockedMicros': {u'r': 3624L, u'w': 104972L}}},
#  u'mem': {u'bits': 64,
#           u'mapped': 160,
#           u'mappedWithJournal': 320,
#           u'resident': 44,
#           u'supported': True,
#           u'virtual': 544},
#  u'metrics': {u'cursor': {u'open': {u'noTimeout': 0L,
#                                     u'pinned': 0L,
#                                     u'total': 0L},
#                           u'timedOut': 0L},
#               u'document': {u'deleted': 0L,
#                             u'inserted': 3L,
#                             u'returned': 13L,
#                             u'updated': 0L},
#               u'getLastError': {u'wtime': {u'num': 0, u'totalMillis': 0},
#                                 u'wtimeouts': 0L},
#               u'operation': {u'fastmod': 0L,
#                              u'idhack': 0L,
#                              u'scanAndOrder': 0L},
#               u'queryExecutor': {u'scanned': 0L, u'scannedObjects': 0L},
#               u'record': {u'moves': 0L},
#               u'repl': {u'apply': {u'batches': {u'num': 0,
#                                                 u'totalMillis': 0},
#                                    u'ops': 0L},
#                         u'buffer': {u'count': 0L,
#                                     u'maxSizeBytes': 268435456,
#                                     u'sizeBytes': 0L},
#                         u'network': {u'bytes': 0L,
#                                      u'getmores': {u'num': 0,
#                                                    u'totalMillis': 0},
#                                      u'ops': 0L,
#                                      u'readersCreated': 0L},
#                         u'preload': {u'docs': {u'num': 0,
#                                                u'totalMillis': 0},
#                                      u'indexes': {u'num': 0,
#                                                   u'totalMillis': 0}}},
#               u'storage': {u'freelist': {u'search': {u'bucketExhausted': 0L,
#                                                      u'requests': 14L,
#                                                      u'scanned': 26L}}},
#               u'ttl': {u'deletedDocuments': 0L, u'passes': 29L}},
#  u'network': {u'bytesIn': 28508, u'bytesOut': 95365, u'numRequests': 444},
#  u'ok': 1.0,
#  u'opcounters': {u'command': 432,
#                  u'delete': 0,
#                  u'getmore': 0,
#                  u'insert': 3,
#                  u'query': 125,
#                  u'update': 0},
#  u'opcountersRepl': {u'command': 0,
#                      u'delete': 0,
#                      u'getmore': 0,
#                      u'insert': 0,
#                      u'query': 0,
#                      u'update': 0},
#  u'pid': 15149L,
#  u'process': u'mongod',
#  u'recordStats': {u'accessesNotInMemory': 0,
#                   u'admin': {u'accessesNotInMemory': 0,
#                              u'pageFaultExceptionsThrown': 0},
#                   u'local': {u'accessesNotInMemory': 0,
#                              u'pageFaultExceptionsThrown': 0},
#                   u'pageFaultExceptionsThrown': 0,
#                   u'test': {u'accessesNotInMemory': 0,
#                             u'pageFaultExceptionsThrown': 0},
#                   u'testdb': {u'accessesNotInMemory': 0,
#                               u'pageFaultExceptionsThrown': 0}},
#  u'uptime': 1873.0,
#  u'uptimeEstimate': 1666.0,
#  u'uptimeMillis': 1872629L,
#  u'version': u'2.6.10',
#  u'writeBacksQueued': False}

# %%
from pymongo import MongoClient
import json

post3 = {"author": "Mike",
         "text": "My first blog post!",
         "tags": ["mongodb", "python", "pymongo"]}
# pprint library is used to make the output look more pretty
from pprint import pprint
# connect to MongoDB, change the << MONGODB URL >> to reflect your own connection string
client = MongoClient('0.0.0.0',27017)
post_id = collection.insert_one(post3)
print post_id # if ObjectId('...') then successful!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d97bf04d4e94> in <module>()
#       9 # connect to MongoDB, change the << MONGODB URL >> to reflect your own connection string
#      10 client = MongoClient('0.0.0.0',27017)
# ---> 11 post_id = collection.insert_one(post3)
#      12 print post_id # if ObjectId('...') then successful!
#
# NameError: name 'collection' is not defined
